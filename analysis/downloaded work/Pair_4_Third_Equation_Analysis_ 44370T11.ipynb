# %%
import numpy as np
from scipy.stats import sobol_indices, uniform
rng = np.random.default_rng()
def f_eq3(x):
    # x[0] = k, (0,1.50)
    # x[1] = gamma_g,
    # x[2] = rho
    # x[3] = drag/s_p
    # x[4] = mu
    # x[5] = C_0
    # x[6] = C_1
    k_1 = 750
    k_2 = 4.5 * 10**7
    C_0 = 0.764404938
    C_1 = -0.938284815

    
    f_eval = C_0 + C_1 * (x[0] * x[1] + (1 - x[1]) * (((-1 * k_2 * x[4]) / (2 * k_1 * (2 * x[2] * x[3]) ** (1/2))) + ((1/k_1) + ((k_2 * x[4]) ** 2 / (8 * (k_1** 2) * x[2] * x[3])))**(1/2))) 
    
    return f_eval
indices = sobol_indices(
    func=f_eq3, n=2**18,
    dists=[
        uniform(loc= 0, scale= 1.5),
        uniform(loc= 0, scale= 1),
        uniform(loc= 0.02, scale= 1.78),
        uniform(loc= 1, scale= 6999),
        uniform(loc= 1 * 10 **-5, scale= 1 * 10 **-5),
        #uniform(loc= 0.5, scale= 1),
        #uniform(loc=-1.5, scale= 3.5),
    ],
    random_state=rng
)
print("first order" , indices.first_order)
print("total order", indices.total_order)
# Out:
# first order [4.42907010e-01 4.09377560e-01 2.28637857e-05 3.18020562e-05
#  3.02629901e-06]
# total order [5.90542994e-01 5.57033003e-01 3.21068723e-05 4.45037561e-05
#  4.83396889e-06]

# %%
boot = indices.bootstrap()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 boot = indices.bootstrap()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_sensitivity_analysis.py:214, in SobolResult.bootstrap(self, confidence_level, n_resamples)
#     210     return self._indices_method(f_A_, f_B_, f_AB_)
#     212 n = self._f_A.shape[1]
# --> 214 res = bootstrap(
#     215     [np.arange(n)], statistic=statistic, method="BCa",
#     216     n_resamples=n_resamples,
#     217     confidence_level=confidence_level,
#     218     bootstrap_result=self._bootstrap_result
#     219 )
#     220 self._bootstrap_result = res
#     222 first_order = BootstrapResult(
#     223     confidence_interval=ConfidenceInterval(
#     224         res.confidence_interval.low[0], res.confidence_interval.high[0]
#    (...)
#     227     standard_error=res.standard_error[0],
#     228 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_resampling.py:663, in bootstrap(data, statistic, n_resamples, batch, vectorized, paired, axis, confidence_level, alternative, method, bootstrap_result, random_state)
#     660 alpha = ((1 - confidence_level)/2 if alternative == 'two-sided'
#     661          else (1 - confidence_level))
#     662 if method == 'bca':
# --> 663     interval = _bca_interval(data, statistic, axis=-1, alpha=alpha,
#     664                              theta_hat_b=theta_hat_b, batch=batch)[:2]
#     665     percentile_fun = _percentile_along_axis
#     666 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_resampling.py:129, in _bca_interval(data, statistic, axis, alpha, theta_hat_b, batch)
#     127 samples = [np.expand_dims(sample, -2) for sample in data]
#     128 theta_hat_i = []
# --> 129 for jackknife_sample in _jackknife_resample(sample, batch):
#     130     samples[j] = jackknife_sample
#     131     broadcasted = _broadcast_arrays(samples, axis=-1)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_resampling.py:54, in _jackknife_resample(sample, batch)
#      51 batch_actual = min(batch_nominal, n-k)
#      53 # jackknife - each row leaves out one observation
# ---> 54 j = np.ones((batch_actual, n), dtype=bool)
#      55 np.fill_diagonal(j[:, k:k+batch_actual], False)
#      56 i = np.arange(n)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\numeric.py:206, in ones(shape, dtype, order, device, like)
#     201 if like is not None:
#     202     return _ones_with_like(
#     203         like, shape, dtype=dtype, order=order, device=device
#     204     )
# --> 206 a = empty(shape, dtype, order, device=device)
#     207 multiarray.copyto(a, 1, casting='unsafe')
#     208 return a
#
# MemoryError: Unable to allocate 64.0 GiB for an array with shape (262144, 262144) and data type bool

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 2, figsize=(9, 4))
_ = axs[0].errorbar(
    ['k', '$ɣ_g$', '$ρ$', '$D/S_p$', '$μ$'], indices.first_order, fmt='o',
    yerr=[
        indices.first_order - boot.first_order.confidence_interval.low,
        boot.first_order.confidence_interval.high - indices.first_order
    ],
)
axs[0].set_ylabel("First order Sobol' indices")
axs[0].set_xlabel('Input parameters')
axs[0].set_xticks(['k', '$ɣ_g$', '$ρ$', '$D/S_p$', '$μ$'])
_ = axs[1].errorbar(
    ['k', '$ɣ_g$', '$ρ$', '$D/S_p$', '$μ$'], indices.total_order, fmt='o',
    yerr=[
        indices.total_order - boot.total_order.confidence_interval.low,
        boot.total_order.confidence_interval.high - indices.total_order
    ],
)
axs[1].set_ylabel("Total order Sobol' indices")
axs[1].set_xlabel('Input parameters')
axs[1].set_xticks(['k', '$ɣ_g$', '$ρ$', '$D/S_p$', '$μ$'])
plt.tight_layout()
plt.show()

# %%
from scipy.stats import qmc

lower = [0, 0, 0.02, 1, 1 * 10**-5]
upper = [1.5, 1, 1.8, 7000, 2* 10**-5]

n_dim = 5
p_labels = ['k', '$ɣ_g$', '$ρ$', '$D/S_p$', '$μ$']
sample = qmc.Sobol(d=n_dim, seed=rng).random(1024)
sample = qmc.scale(
    sample=sample,
    l_bounds=lower,
    u_bounds=upper
)
output = f_eq3(sample.T)

# %%
fig, ax = plt.subplots(1, n_dim, figsize=(30, 10))
for i in range(n_dim):
    xi = sample[:, i]
    ax[i].scatter(xi, output, marker='+')
    ax[i].set_xlabel(p_labels[i])
ax[0].set_ylabel('Y')
plt.tight_layout()
plt.show()

# %%
for z in range(n_dim):
    mini = np.min(output)
    maxi = np.max(output)
    n_bins = 10
    bins = np.linspace(lower[z], upper[z], num=n_bins, endpoint=False)
    dx = bins[1] - bins[0]
    fig, ax = plt.subplots(1, 1, figsize=(8, 8))
    xi = sample[:, z]
    ax.scatter(xi, output, marker='+')
    ax.set_xlabel(p_labels[z])
    for bin_ in bins:
        idx = np.where((bin_ <= xi) & (xi <= bin_ + dx))
        xi_ = xi[idx]
        y_ = output[idx]
        ave_y_ = np.mean(y_)
        ax.plot([bin_ + dx/2] * 2, [mini, maxi], c='k')
        ax.scatter(bin_ + dx/2, ave_y_, c='r')
    ax.set_ylabel('Y')
    plt.tight_layout()
    plt.show()
